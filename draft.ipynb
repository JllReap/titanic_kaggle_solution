# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # statistical data visualization

import warnings  # Base category for warnings triggered during the process of importing a module (ignored by default)
warnings.filterwarnings('ignore')  # here we prescribe the action in case of an error.

# %%
paths = {
    "test": "./titanic/test.csv",
    "train": "./titanic/train.csv",
    "submission": "./titanic/gender_submission.csv"
}

# %%
test_df = pd.read_csv(paths['test'])
train_df = pd.read_csv(paths['train'])

# %% [markdown]
# # Some EDA

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.pairplot(train_df)

# %%
train_df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
train_df.groupby('Ticket')['Ticket'].transform('count')
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    2
# 889    1
# 890    1
# Name: Ticket, Length: 891, dtype: int64

# %%
train_df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 329          330         1       1
# 219          220         0       2
# 44            45         1       3
# 296          297         0       3
# 571          572         1       1
# 138          139         0       3
# 710          711         1       1
# 216          217         1       3
# 826          827         0       3
# 746          747         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 329                      Hippach, Miss. Jean Gertrude  female  16.0      0
# 219                                Harris, Mr. Walter    male  30.0      0
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 296                                Hanna, Mr. Mansour    male  23.5      0
# 571     Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0      2
# 138                               Osen, Mr. Olaf Elon    male  16.0      0
# ...

# %%
plt.hist(train_df["Fare"])
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.pairplot(train_df, hue="Survived")

# %%
plt.hist(train_df['Age']);

# %%
train_df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
train_df["Pclass"].unique().tolist()
# Out:
# [3, 1, 2]

# %%
train_df[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
train_df['Pclass'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.countplot(x="Survived", hue="Pclass", data=train_df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
train_df["Ticket"].describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
pd.crosstab([train_df.Embarked, train_df.Pclass],[train_df.Sex,train_df.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_eb704_row0_col0, #T_eb704_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_eb704_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_eb704_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_eb704_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_eb704_row0_col4, #T_eb704_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_eb704_row1_col0, #T_eb704_row3_col0, #T_eb704_row3_col1, #T_eb704_row3_col2, #T_eb704_row3_col3, #T_eb704_row3_col4, #T_eb704_row4_col0, #T_eb704_row4_col2, #T_eb704_row4_col3, #T_eb704_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_eb704_row1_col1, #T_eb704_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_eb704_row1_col3, #T_eb704_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_eb704_row2_col0, #T_eb704_row5_col1 {
#   background-color: #e6f266;
# ...

# %% [markdown]
# # Data Preparation

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Fill NA

# %%
train_df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
train_df[["Age", "Sex"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
train_df.loc[:, "Embarked"] = train_df.loc[:, "Embarked"].fillna("S")
train_df.loc[train_df["Sex"] == "male", 'Age'] = train_df.loc[train_df["Sex"] == "male", 'Age'].fillna(31)
train_df.loc[train_df["Sex"] == "female", 'Age'] = train_df.loc[train_df["Sex"] == "female", 'Age'].fillna(27)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Dropping cols

# %%
train_df["Ticket"].describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
cols_to_drop = ['Cabin', 'PassengerId', 'Ticket', 'Name']
train_df = train_df.drop(cols_to_drop, axis = 1)

# %%
train_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### Finding anomalies

# %%
def find_outliers(df, cols):
    bounds = {}
    cols = list(cols)

    for col in cols:
        s = df[col].dropna()
        q1 = s.quantile(0.25)
        q3 = s.quantile(0.75)
        iqr = q3 - q1
        low = q1 - 1.5 * iqr
        high = q3 + 1.5 * iqr
        
        bounds[col] = (low, high)

    return bounds

# %%
num_cols = ['Age', 'Fare']

# %%
find_outliers(train_df, num_cols)
# Out:
# {'Age': (np.float64(2.5), np.float64(54.5)),
#  'Fare': (np.float64(-26.724), np.float64(65.6344))}

# %%
train_df.dt
